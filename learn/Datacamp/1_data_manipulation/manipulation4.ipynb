# %% [markdown]
# ## Data Visualisation

# %% [markdown]
# we use the pyplot to display the visuals

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
sales_df = pd.read_csv(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Datacamp\data_manipulation\sales_subset.csv")

# %%
sales_df.head(3)
# Out:
#    Unnamed: 0  store type  department       date  weekly_sales  is_holiday  \
# 0           0      1    A           1 2010-02-05      24924.50       False
# 1           1      1    A           1 2010-03-05      21827.90       False
# 2           2      1    A           1 2010-04-02      57258.43       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment  year
# 0       5.727778              0.679451         8.106  2010
# 1       8.055556              0.693452         8.106  2010
# 2      16.816667              0.718284         7.808  2010

# %%
sales_df['year'] = sales_df['year'].astype(str)

# %%
sales_df['date'] = pd.to_datetime(sales_df['date'])

# %%
#create histogram on fuel_price_usd_per_l

# using mtplt package
# plt.hist(sales_df["fuel_price_usd_per_l"])
# plt.show()

#usinh hist as method
sales_df["fuel_price_usd_per_l"].hist(bins=70)
# plt.show()
# Out:
# <Axes: >

# %%
sales_df["year"] = sales_df["date"].dt.year

# %%
#bar plots - it shows relationship bw categorical and quantitative data

#using method
# sales_df.plot( x="year", y="weekly_sales",  kind ="bar")

# using package
plt.bar(sales_df["year"],sales_df["weekly_sales"])
plt.show()

# %%
#line

sales_df.plot(x="year", y="weekly_sales", kind="line")
plt.show()

# %%
sales_df.head(1)
# Out:
#    Unnamed: 0  store type  department       date  weekly_sales  is_holiday  \
# 0           0      1    A           1 2010-02-05       24924.5       False
#
#    temperature_c  fuel_price_usd_per_l  unemployment  year
# 0       5.727778              0.679451         8.106  2010

# %%
#scatter
sales_df.plot(x="fuel_price_usd_per_l",y="unemployment",kind="scatter")
# Out:
# <Axes: xlabel='fuel_price_usd_per_l', ylabel='unemployment'>

# %% [markdown]
# ### unpickling

# %%
import pickle
from pprint import pprint

# %%
# Read data from pickle file
with open(r'C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Datacamp\data_manipulation\avoplotto.pkl', 'rb') as f:
    objectot = pickle.load(f)
    
# Report data type of object loaded from pickle file
print('type(object): ', type(objectot))

# Print the variables of the object loaded from pickle file
pprint(vars(objectot))
# Out:
# type(object):  <class 'pandas.core.frame.DataFrame'>
# {'_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_item_cache': {},
#  '_metadata': [],
#  '_mgr': BlockManager
# Items: Index(['date', 'type', 'year', 'avg_price', 'size', 'nb_sold'], dtype='object')
# Axis 1: RangeIndex(start=0, stop=1014, step=1)
# NumpyBlock: slice(3, 7, 2), 2 x 1014, dtype: float64
# NumpyBlock: slice(2, 3, 1), 1 x 1014, dtype: int64
# NumpyBlock: [0 1 4], 3 x 1014, dtype: object,
#  '_typ': 'dataframe'}

# %%
avocados = objectot

avocados.head(3)
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66

# %% [markdown]
# done!

# %% [markdown]
# ## Excercises

# %% [markdown]
# 1. I want to know which size of avocados is sold most? I can just go ahead and use barchart
# 2. using bar chart - do the group by and assign a variable
# 3. that variable can be used to build bar chart i.e using 'plot' method & 'kind="bar"' argument

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Look at the first few rows of data
print(avocados.head())

# Get the total number of avocados sold of each size
nb_sold_by_size = avocados.groupby('size')["nb_sold"].sum()

# Create a bar plot of the number of avocados sold by size
nb_sold_by_size.plot(kind='bar')

# Show the plot
plt.show()

# %% [markdown]
# 1. I want to get sales trend
# 2. i use line chart - standard! , but by date
# 3. using groupby, plot method and kind argument

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

print(avocados.head())

# Get the total number of avocados sold on each date
nb_sold_by_date = avocados.groupby("date")['nb_sold'].sum()

# Create a line plot of the number of avocados sold by date
nb_sold_by_date.plot(kind="line")

# Show the plot
plt.show()
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66
# 3  2015-12-06  conventional  2015       0.89  small  9405464.36
# 4  2015-11-29  conventional  2015       0.99  small  8094803.56

# %% [markdown]
# 1. i want to understand supply and demand (which is denoteed by relation bw to continous variables - qnty & price)
# 2. i used scatter plot!

# %%
# Scatter plot of avg_price vs. nb_sold with title
avocados.plot(x='nb_sold',y='avg_price',kind='scatter',title = "Demand & supply")

# Show the plot
plt.show()

# %%
avocados.head(3)
# Out:
#          date          type  year  avg_price   size     nb_sold
# 0  2015-12-27  conventional  2015       0.95  small  9626901.09
# 1  2015-12-20  conventional  2015       0.98  small  8710021.76
# 2  2015-12-13  conventional  2015       0.93  small  9855053.66

# %%
# Modify bins to 20
avocados[avocados["type"] == "conventional"]["avg_price"].hist(alpha=0.5,bins=20)

# Modify bins to 20
avocados[avocados["type"] == "organic"]["avg_price"].hist(alpha=0.5,bins=20)

# Add a legend
plt.legend(["conventional", "organic"])

# Show the plot
plt.show()

# %%
["nb_sold"].hist()

# %% [markdown]
# ### Missing values
# Nan - Not a number
# isna() method gives boolean values
# .any() on isna method (method on method) gives boolean on column
# isna() can be used to built chart and see number of na's

# %%
# Import matplotlib.pyplot with alias plt
import matplotlib.pyplot as plt

# Check individual values for missing values
print(avocados.isna())

# Check each column for missing values
print(avocados.isna().any())

# Bar plot of missing values by variable
avocados.isna().sum().plot(kind='bar')

# Show plot
plt.show()


# Remove rows with missing values
avocados_complete = avocados_2016.dropna()

# Check if any columns contain missing values
print(avocados_complete.isna().any())

# %% [markdown]
# handling missing values (by filling with 0)

# %%
# List the columns with missing values
cols_with_missing = ["small_sold", "large_sold", "xl_sold"]

# Create histograms showing the distributions cols_with_missing
avocados_2016[cols_with_missing].hist()

# Show the plot
plt.show()


# Fill in missing values with 0
avocados_filled = avocados_2016.fillna(0)

# Create histograms of the filled columns
avocados_filled[cols_with_missing].hist()

# Show the plot
plt.show()

# %% [markdown]
# creating df

# %%
#list of dictionaries
avocados_list = [
    {"date":"2019-11-03","small_sold":10376832,"large_sold":7835071},
    {"date":"2019-11-10","small_sold":10717154,"large_sold":8561348}
]

avocados_2019 = pd.DataFrame(avocados_list)
avocados_2019
# Out:
#          date  small_sold  large_sold
# 0  2019-11-03    10376832     7835071
# 1  2019-11-10    10717154     8561348

# %%
#dictionary of lists

avocados_dict = {
    "date":["2019-11-03","2019-11-10"],
    "small_sold":["10376832","10717154"],
    "large_sold":["10717154","8561348"]
}

avocados_dict

avocados_2019 = pd.DataFrame(avocados_dict)
avocados_2019
# Out:
#          date small_sold large_sold
# 0  2019-11-03   10376832   10717154
# 1  2019-11-10   10717154    8561348

# %% [markdown]
# Reading and writing csv

# %% [markdown]
# END
