# %%
import pandas as pd

# %% [markdown]
# # Data upload & sanity check

# %%
bonus_cost = pd.read_excel(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Full_projects\Game_analytics_lognormal\BonusCost_Data.xlsx")
first_bet = pd.read_excel(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Full_projects\Game_analytics_lognormal\First_Bet_Data.xlsx")
first_deposit = pd.read_excel(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Full_projects\Game_analytics_lognormal\First_Deposit_Data.xlsx")
Pl_activity = pd.read_excel(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Full_projects\Game_analytics_lognormal\Player_Activity_Data.xlsx")
pl_details = pd.read_excel(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Full_projects\Game_analytics_lognormal\Player_Details.xlsx")

# %%
first_deposit = pd.read_excel(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Full_projects\Game_analytics_lognormal\First_Deposit_Data.xlsx")

# %%
bonus_cost.columns = bonus_cost.iloc[0]
bonus_cost = bonus_cost[1:].reset_index(drop=True)

# first_bet.columns = first_bet.iloc[0]
# first_bet = first_bet[1:].reset_index(drop=True)

# first_deposit.columns = first_deposit.iloc[0]
# first_deposit = first_deposit[1:].reset_index(drop=True)

# Pl_activity.columns = Pl_activity.iloc[0]
# Pl_activity = Pl_activity[1:].reset_index(drop=True)

# pl_details.columns = pl_details.iloc[0]
# pl_details = pl_details[1:].reset_index(drop=True)

# %%
bonus_cost = bonus_cost.drop(bonus_cost.columns[0], axis=1)

# %%
bonus_cost.describe()
# Out:
# C:\Users\vshnu\AppData\Local\Temp\ipykernel_26512\3204865855.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   bonus_cost.describe()
# 0       Src_PLAYER_ID        ActivityMonth  Product  BONUS_COST
# count          207070               207070   207070      207070
# unique         100749                   30        2        7518
# top          12412144  2021-04-30 00:00:00  eGaming          50
# freq               36                12895   150191       19114

# %%
bonus_cost["Product"].value_counts()
# Out:
# Product
# eGaming       150191
# SportsBook     56879
# Name: count, dtype: int64

# %%
first_deposit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292785 entries, 0 to 292784
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Src_Player_Id          292785 non-null  object
#  1   First_Deposit_Date     127261 non-null  object
#  2   First_Deposit_Channel  127261 non-null  object
#  3   First_Deposit_Method   127261 non-null  object
#  4   First_Deposit_Amount   127261 non-null  object
# dtypes: object(5)
# memory usage: 11.2+ MB

# %%
first_deposit = first_deposit.drop(first_deposit.columns[0], axis=1)

# %%
first_deposit.head(2)
# Out:
# 0 Src_Player_Id First_Deposit_Date First_Deposit_Channel First_Deposit_Method  \
# 0      13472812                NaN                   NaN                  NaN
# 1      13331793                NaN                   NaN                  NaN
#
# 0 First_Deposit_Amount
# 0                  NaN
# 1                  NaN

# %%
first_deposit.columns = first_deposit.iloc[0]
first_deposit = first_deposit[1:].reset_index(drop=True)

# %%
first_deposit["First_Deposit_Channel"].value_counts()
# Out:
# First_Deposit_Channel
# Online    98483
# Retail    28778
# Name: count, dtype: int64

# %%
first_deposit["First_Deposit_Method"].value_counts()
# Out:
# First_Deposit_Method
# VISA                 53677
# RetailDeposit        28778
# MC                   27880
# PaysafecardViaSC     13589
# MAESTRO               2664
# MoneyBookersViaSC      599
# NetellerviaSC           71
# Correction               3
# Name: count, dtype: int64

# %%
first_bet.head(2)
# Out:
# 0 Src_Player_Id   System_First_Bet_Datetime System_First_BetSlip_Amt  \
# 0      15643431         2020-10-09 03:57:29                      2.5
# 1      13593034  2019-09-27 15:03:58.244000                       10
#
# 0 System_First_Bet_Product_Group System_First_Bet_Product  \
# 0                        eGaming          Non Table Games
# 1                         Sports                 Prematch
#
# 0 System_First_Bet_Channel System_First_Bet_Platform
# 0                   Online                    Mobile
# 1                   Online                    Mobile

# %%
first_bet = first_bet.drop(first_bet.columns[0], axis=1)

# %%
first_bet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292785 entries, 0 to 292784
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Src_Player_Id                   292785 non-null  object
#  1   System_First_Bet_Datetime       159166 non-null  object
#  2   System_First_BetSlip_Amt        159166 non-null  object
#  3   System_First_Bet_Product_Group  159166 non-null  object
#  4   System_First_Bet_Product        159166 non-null  object
#  5   System_First_Bet_Channel        159166 non-null  object
#  6   System_First_Bet_Platform       159166 non-null  object
# dtypes: object(7)
# memory usage: 15.6+ MB

# %%
first_bet["System_First_Bet_Product_Group"].value_counts()
# Out:
# System_First_Bet_Product_Group
# eGaming    94593
# Sports     61351
# Lotto       1742
# Lottery     1113
# IVG          367
# Name: count, dtype: int64

# %%
first_bet["System_First_Bet_Product"].value_counts()
# Out:
# System_First_Bet_Product
# Non Table Games    91147
# Prematch           44898
# Live               16453
# Table Games         3446
# Lotto               1742
# Lucky Six           1017
# IVG                  367
# LuckyX                72
# Next Six              24
# Name: count, dtype: int64

# %%
first_bet["System_First_Bet_Platform"].value_counts()
# Out:
# System_First_Bet_Platform
# Mobile    127948
# Web        31218
# Name: count, dtype: int64

# %%
first_bet["System_First_Bet_Channel"].value_counts()
# Out:
# System_First_Bet_Channel
# Online    159166
# Name: count, dtype: int64

# %%
Pl_activity.head(2)
# Out:
# 0 src_player_id        ActivityMonth     Product SubProduct ActivePlayerDays  \
# 0      16585649  2020-08-31 00:00:00  SportsBook   Livebook                1
# 1      12845036  2019-05-31 00:00:00  SportsBook   Prematch               28
#
# 0 Bet_Amount Win_Amount Gross_Win Net_Gross_Win
# 0        500          0       500           420
# 1    1229.48    1177.85     41.63       34.9692

# %%
Pl_activity.columns = Pl_activity.iloc[0]
Pl_activity = Pl_activity[1:].reset_index(drop=True)

# %%
Pl_activity = Pl_activity.drop(Pl_activity.columns[0], axis =1)

# %%
pl_details.head(2)
# Out:
#    Unnamed: 0     Unnamed: 1           Unnamed: 2           Unnamed: 3  \
# 0         NaN  Src_Player_Id          Signup_Date  acquisition_channel
# 1         NaN       12584958  2019-02-23 17:24:49                  NaN
#
#           Unnamed: 4 Unnamed: 5           Unnamed: 6          Unnamed: 7
# 0  src_advertiser_id     Gender        Date_Of_Birth  Internal_Player_YN
# 1             999999         M   1991-08-05 00:00:00                  N

# %%
pl_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292785 entries, 0 to 292784
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Src_Player_Id        292785 non-null  object
#  1   Signup_Date          292785 non-null  object
#  2   acquisition_channel  201279 non-null  object
#  3   src_advertiser_id    290719 non-null  object
#  4   Gender               292774 non-null  object
#  5   Date_Of_Birth        292785 non-null  object
#  6   Internal_Player_YN   292785 non-null  object
# dtypes: object(7)
# memory usage: 15.6+ MB

# %%
pl_details.columns = pl_details.iloc[0]
pl_details = pl_details[1:].reset_index(drop=True)

# %%
pl_details = pl_details.drop(pl_details.columns[0], axis=1)

# %% [markdown]
# # Cohort Analysis

# %%
print(pl_details.head(2))
print(Pl_activity.head(2))
print(first_bet.head(2))
print(first_deposit.head(2))
print(bonus_cost.head(2))
# Out:
# 0 Src_Player_Id          Signup_Date acquisition_channel src_advertiser_id  \
# 0      12584958  2019-02-23 17:24:49                 NaN            999999
# 1      12356925  2019-01-07 15:57:11                 NaN            999999
#
# 0 Gender        Date_Of_Birth Internal_Player_YN
# 0     M   1991-08-05 00:00:00                 N
# 1     M   1993-09-09 00:00:00                 N
# 0 src_player_id        ActivityMonth     Product SubProduct ActivePlayerDays  \
# 0      16585649  2020-08-31 00:00:00  SportsBook   Livebook                1
# 1      12845036  2019-05-31 00:00:00  SportsBook   Prematch               28
#
# 0 Bet_Amount Win_Amount Gross_Win Net_Gross_Win
# 0        500          0       500           420
# 1    1229.48    1177.85     41.63       34.9692
# 0 Src_Player_Id   System_First_Bet_Datetime System_First_BetSlip_Amt  \
# 0      15643431         2020-10-09 03:57:29                      2.5
# 1      13593034  2019-09-27 15:03:58.244000                       10
#
# ...

# %%
# data needed: Src_Player_Id ,Signup_Date, acquisition_channel,
# src_player_id        ActivityMonth     Product Net_Gross_Win  ,
# BONUS_COST, Src_PLAYER_ID  , ActivityMonth

# %%
Pl_activity_ca = Pl_activity[["src_player_id", "ActivityMonth","Product","Net_Gross_Win","ActivePlayerDays"]]

# %%
bonus_cost.head(1)
# Out:
# 0 Src_PLAYER_ID        ActivityMonth  Product BONUS_COST
# 0      16051927  2020-06-30 00:00:00  eGaming         50

# %%
Pl_activity_ca = Pl_activity_ca.merge(bonus_cost, how="left", left_on=["src_player_id", "ActivityMonth"],
                                      right_on=["Src_PLAYER_ID","ActivityMonth"])

# %%
Pl_activity_ca.head(2)
# Out:
# 0 src_player_id        ActivityMonth   Product_x Net_Gross_Win  \
# 0      16585649  2020-08-31 00:00:00  SportsBook           420
# 1      12845036  2019-05-31 00:00:00  SportsBook       34.9692
#
# 0 ActivePlayerDays Src_PLAYER_ID Product_y BONUS_COST
# 0                1           NaN       NaN        NaN
# 1               28           NaN       NaN        NaN

# %%
Pl_activity_ca = Pl_activity_ca.drop(columns=["Product_y","Src_PLAYER_ID"])

# %%
pl_details.head(2)
# Out:
# 0 Src_Player_Id          Signup_Date acquisition_channel src_advertiser_id  \
# 0      12584958  2019-02-23 17:24:49                 NaN            999999
# 1      12356925  2019-01-07 15:57:11                 NaN            999999
#
# 0 Gender        Date_Of_Birth Internal_Player_YN
# 0     M   1991-08-05 00:00:00                 N
# 1     M   1993-09-09 00:00:00                 N

# %%
pl_details_sub = pl_details[["Src_Player_Id","Signup_Date","acquisition_channel"	]]

# %%
Pl_activity_ca = Pl_activity_ca.merge(pl_details_sub, how="left", left_on="src_player_id",
                                      right_on="Src_Player_Id")

# %% [markdown]
# ### final data for cohort analysis

# %%
Pl_activity_ca.head(2)
# Out:
# 0 src_player_id        ActivityMonth   Product_x Net_Gross_Win  \
# 0      16585649  2020-08-31 00:00:00  SportsBook           420
# 1      12845036  2019-05-31 00:00:00  SportsBook       34.9692
#
# 0 ActivePlayerDays BONUS_COST Src_Player_Id          Signup_Date  \
# 0                1        NaN      16585649  2020-08-06 12:27:56
# 1               28        NaN      12845036  2019-04-20 22:05:39
#
# 0 acquisition_channel
# 0                 PPC
# 1                 PPC

# %%
Pl_activity_ca["revenue"] = Pl_activity_ca["Net_Gross_Win"] - Pl_activity_ca["BONUS_COST"]

# %%
# get cohort month (y-m format), get activity_month (y-m fomart), get_period (cohort_month-activity month)

# %%
Pl_activity_ca.dtypes
# Out:
# 0
# src_player_id          object
# ActivityMonth          object
# Product_x              object
# Net_Gross_Win          object
# ActivePlayerDays       object
# BONUS_COST             object
# Src_Player_Id          object
# Signup_Date            object
# acquisition_channel    object
# revenue                object
# dtype: object

# %%
Pl_activity_ca["ActivityMonth"] = pd.to_datetime(Pl_activity_ca["ActivityMonth"])
Pl_activity_ca["Signup_Date"] = pd.to_datetime(Pl_activity_ca["Signup_Date"])

# %%
Pl_activity_ca["Cohort_month"] =  Pl_activity_ca["Signup_Date"].dt.strftime("%y-%m")

# %%
## fucntion to help us get month, year separatly, which will be used to calculate period

def get_m_y(df,column):
    year = df[column].dt.year
    month = df[column].dt.month
    return year, month

# %%
act_year, act_month = get_m_y(Pl_activity_ca,"ActivityMonth")
coh_year, coh_month = get_m_y(Pl_activity_ca,"Signup_Date")

# %%
Pl_activity_ca["period"] = (act_year-coh_year)*12 + (act_month-coh_month)

# %%
Pl_activity_ca.head(2)
# Out:
# 0 src_player_id ActivityMonth   Product_x Net_Gross_Win ActivePlayerDays  \
# 0      16585649    2020-08-31  SportsBook           420                1
# 1      12845036    2019-05-31  SportsBook       34.9692               28
#
# 0 BONUS_COST Src_Player_Id         Signup_Date acquisition_channel revenue  \
# 0        NaN      16585649 2020-08-06 12:27:56                 PPC     NaN
# 1        NaN      12845036 2019-04-20 22:05:39                 PPC     NaN
#
# 0 Cohort_month  period
# 0        20-08       0
# 1        19-04       1

# %%
coh_by_month1 = Pl_activity_ca.groupby(["Cohort_month", "period"]).agg(
    user_count=("src_player_id", "count"),
    total_revenue=("revenue", "sum")
).reset_index()

# %%
type(coh_by_month1)
# Out:
# pandas.core.frame.DataFrame

# %%
coh_by_month1.head(1)
# Out:
#   Cohort_month  period  user_count total_revenue
# 0        19-01       0        8590 -45174.063188

# %%
initial_users = coh_by_month1[coh_by_month1["period"] == 0][["Cohort_month", "user_count"]]

# %%
initial_users.head(1)
# Out:
#   Cohort_month  user_count
# 0        19-01        8590

# %%
initial_users = initial_users.rename(columns={"user_count":"initial_users"})

# %%
coh_by_month1 = coh_by_month1.merge(initial_users, on="Cohort_month")

# %%
coh_by_month1.head(1)
# Out:
#   Cohort_month  period  user_count total_revenue  initial_users
# 0        19-01       0        8590 -45174.063188           8590

# %%
coh_by_month1["percent_users"] = (coh_by_month1["user_count"]/coh_by_month1["initial_users"])*100

# %%
cohort_analysis_month = coh_by_month1.pivot(index="Cohort_month",columns="period",values="percent_users")
cohort_analysis_month
# Out:
# period           0          1          2          3          4          5   \
# Cohort_month
# 19-01         100.0  38.032596  18.917346  18.335274  13.364377  11.350407
# 19-02         100.0  41.541756  27.320821  18.239073  14.132762  12.961330
# 19-03         100.0  49.343186  24.288451  18.007663  14.928845  15.708812
# 19-04         100.0  42.457660  19.285808  15.347250  15.189707  15.570435
# 19-05         100.0  35.175316  17.138850  16.058906  14.151473  16.072931
# 19-06         100.0  33.925585  20.882107  17.892977  17.683946  16.555184
# 19-07         100.0  41.322474  23.792903  21.950747  22.183440  21.330231
# 19-08         100.0  40.753963  26.003142  22.576039  22.518920  19.605883
# 19-09         100.0  46.737305  27.522936  23.543093  21.062153  18.736271
# 19-10         100.0  49.229111  28.743935  23.083558  20.377358  19.083558
# 19-11         100.0  49.283719  23.858005  20.037841  18.343995  10.316245
# ...

# %%
cohort_analysis_month.to_csv("cohort_analysis_month.csv")

# %%
cohort_analysis_revenue = coh_by_month1.pivot(index="Cohort_month",columns="period",values="total_revenue")
cohort_analysis_revenue
# Out:
# period                   0              1              2              3   \
# Cohort_month
# 19-01         -45174.063188  319274.162417   75349.122708  119558.254065
# 19-02          64286.949315   -5306.744667   84376.763159    54022.84931
# 19-03           9621.029342    9057.641975   78400.701251   43047.335526
# 19-04         149187.099646   99655.854713   39147.401232   51926.333127
# 19-05         134330.586614   130430.92676  127224.731129    8800.172819
# 19-06         -10144.055342   16277.876017   81366.977405   21887.061986
# 19-07            6797.60671   75044.314343    76057.83552   22822.725933
# 19-08          -66259.07897  185356.053831   194636.29898  298220.714421
# 19-09         -69310.146807  108698.369866  241961.870366  439033.101039
# 19-10         -37435.413474  162395.623507 -152414.939108   18832.104788
# 19-11        -190301.503408   81797.026803   89853.598465  170588.772785
# 19-12         -58539.741004  127938.315605   95704.819224   38212.586527
# ...

# %%
cohort_analysis_revenue.to_csv("cohort_analysis_revenue.csv")

# %% [markdown]
# # Cohort Analysis (DC)

# %%
online = pd.read_csv(r"C:\Users\vshnu\OneDrive\Desktop\Vishnuperson\RE\aspire_\learn\Full_projects\Game_analytics_lognormal\online.csv")

# %%
online.head(2)
# Out:
#    InvoiceNo StockCode                    Description  Quantity  \
# 0     572558     22745     POPPY'S PLAYHOUSE BEDROOM          6
# 1     577485     23196  VINTAGE LEAF MAGNETIC NOTEPAD         1
#
#           InvoiceDate  UnitPrice  CustomerID         Country invoice_month
# 0 2011-10-25 08:26:00       2.10       14286  United Kingdom    2011-10-01
# 1 2011-11-20 11:56:00       1.45       16360  United Kingdom    2011-11-01

# %%
#droppning a first colmn which was redundant, usinf frop method on df. , axis=1 is mus, because we want to drop column, column is dentod by axis=1
# default is axis=0, which is denoted by row. so it is important to provide axis=1.
online = online.drop(online.columns[0], axis = 1)

# ?Pl_activity = Pl_activity.drop(Pl_activity.columns[0], axis =1)

# %%
import datetime as dt

# %%
type(online["InvoiceDate"])
# Out:
# pandas.core.series.Series

# %%
# we use pandas to convert str to datetime
online["InvoiceDate"] = pd.to_datetime(online["InvoiceDate"])

# %%
# x is the column (or series) that will be provided, it will return, year, month and day as default 1

def get_month(x):
    return dt.datetime(x.year, x.month, 1)

# %%
online["invoice_month"] = online["InvoiceDate"].apply(get_month)

# %%
# get the cohorth month for each sutome rpopluated. for this we use group by (so we group by custoemr id and get invoice monht)
# but use transform method to get only min (given "min" in quotes)
online["Cohort_month"] = online.groupby("CustomerID")["invoice_month"].transform("min")

# %%
online.head(1)
# Out:
#    InvoiceNo StockCode                 Description  Quantity  \
# 0     572558     22745  POPPY'S PLAYHOUSE BEDROOM          6
#
#           InvoiceDate  UnitPrice  CustomerID         Country invoice_month  \
# 0 2011-10-25 08:26:00        2.1       14286  United Kingdom    2011-10-01
#
#   Cohort_month  period
# 0   2011-04-01       6

# %%
# next we need to get index number. this is on the column
# is num of month bw cohort month and invoice month, if croses a year, it need to be multiplied by 12. 

def m_y(dataf, column):
    year = column.dt.year 
    month = column.dt.month
    return year, month

# %%
invoice_yr, invoice_mt = m_y(online, online["InvoiceDate"])
cohort_yr, cohort_mt = m_y(online, online["Cohort_month"])

# %%
online["period"] = (invoice_yr-cohort_yr)*12 + (invoice_mt-cohort_mt)

# %%
type(ch_data)
# Out:
# pandas.core.frame.DataFrame

# %%
ch_data = online.groupby(["Cohort_month","period"])["CustomerID"].apply(pd.Series.nunique)

# %%
ch_data = ch_data.reset_index()

# %%
type(ch_data)
# Out:
# pandas.core.frame.DataFrame

# %%
ch_counts =ch_data.pivot(index='Cohort_month',columns='period',values='CustomerID')
ch_counts

# %%
coh_size = ch_counts.iloc[:,0]
coh_size

# %%
type(coh_size)
# Out:
# pandas.core.series.Series

# %%
retention = ch_counts.divide(coh_size, axis=0)

# %%
retention.round(3)*100

# %%
#1. convert invoice data from obj str
#2. create a function, that returns as (YYYY-MM-01)
#3. get the min of invoice data and name it as cohort month (use transform & groupby)
#4. create a funciton, that get y,m,d from series, and use it to name and calculate the perido.
#5. once period is caluclated, create a series that will group on id, cohort monhth and get uniques (used in apply)
#6. reset index to convert to df
#7. create a pivot table
#8. get retention rate by taking iloc of just period = 1
#9. then divide by every rows(use axis=0) on ch_count df.

# %%
online.head(2)
# Out:
#    InvoiceNo StockCode                    Description  Quantity  \
# 0     572558     22745     POPPY'S PLAYHOUSE BEDROOM          6
# 1     577485     23196  VINTAGE LEAF MAGNETIC NOTEPAD         1
#
#           InvoiceDate  UnitPrice  CustomerID         Country invoice_month  \
# 0 2011-10-25 08:26:00       2.10       14286  United Kingdom    2011-10-01
# 1 2011-11-20 11:56:00       1.45       16360  United Kingdom    2011-11-01
#
#   Cohort_month  period
# 0   2011-04-01       6
# 1   2011-09-01       2

# %%
#average quantity cohort analysis.

coh_qnty = online.groupby(["Cohort_month","period"])["Quantity"].mean()
# Out:
#    Cohort_month  period   Quantity
# 0    2010-12-01       0  11.111588
# 1    2010-12-01       1  12.260241
# 2    2010-12-01       2  12.152314
# 3    2010-12-01       3  13.228676
# 4    2010-12-01       4  13.669839
# ..          ...     ...        ...
# 86   2011-10-01       1   7.452211
# 87   2011-10-01       2   5.987654
# 88   2011-11-01       0   7.840920
# 89   2011-11-01       1   7.145455
# 90   2011-12-01       0  21.336538
#
# [91 rows x 3 columns]

# %%
coh_qnty = coh_qnty.reset_index()

# %%
averag_qunatity_cohort = coh_qnty.pivot(index="Cohort_month", columns="period",values="Quantity")

# %%
avg_start_q = averag_qunatity_cohort.iloc[:,0]

# %%
qnty_ret = averag_qunatity_cohort.divide(avg_start_q, axis = 0)
qnty_ret
# Out:
# period         0         1         2         3         4         5         6   \
# Cohort_month
# 2010-12-01    1.0  1.103374  1.093661  1.190530  1.230233  1.015933  0.955826
# 2011-01-01    1.0  0.989658  0.917538  0.929871  1.318194  1.208934  1.596232
# 2011-02-01    1.0  1.179739  0.874635  0.947032  1.441977  1.002971  1.428615
# 2011-03-01    1.0  1.490224  1.356704  1.064292  1.685789  1.324887  1.211035
# 2011-04-01    1.0  1.120069  1.258767  1.167627  1.154165  0.779694  1.054573
# 2011-05-01    1.0  0.681197  1.082236  0.820383  0.845140  0.602743  0.693366
# 2011-06-01    1.0  1.514646  1.703322  1.059455  1.174374  0.681461  0.917323
# 2011-07-01    1.0  1.497844  0.510753  0.919762  0.570037  0.640885       NaN
# 2011-08-01    1.0  0.700545  0.523600  0.542572  0.572941       NaN       NaN
# 2011-09-01    1.0  0.545962  0.728311  0.856800       NaN       NaN       NaN
# 2011-10-01    1.0  0.802507  0.644793       NaN       NaN       NaN       NaN
# ...

# %%
qnty_ret = qnty_ret.round(2)*100

# %%
qnty_ret
# Out:
# period           0      1      2      3      4      5      6      7      8   \
# Cohort_month
# 2010-12-01    100.0  110.0  109.0  119.0  123.0  102.0   96.0  115.0  119.0
# 2011-01-01    100.0   99.0   92.0   93.0  132.0  121.0  160.0  151.0  172.0
# 2011-02-01    100.0  118.0   87.0   95.0  144.0  100.0  143.0  109.0  111.0
# 2011-03-01    100.0  149.0  136.0  106.0  169.0  132.0  121.0  120.0   94.0
# 2011-04-01    100.0  112.0  126.0  117.0  115.0   78.0  105.0   95.0   67.0
# 2011-05-01    100.0   68.0  108.0   82.0   85.0   60.0   69.0   52.0    NaN
# 2011-06-01    100.0  151.0  170.0  106.0  117.0   68.0   92.0    NaN    NaN
# 2011-07-01    100.0  150.0   51.0   92.0   57.0   64.0    NaN    NaN    NaN
# 2011-08-01    100.0   70.0   52.0   54.0   57.0    NaN    NaN    NaN    NaN
# 2011-09-01    100.0   55.0   73.0   86.0    NaN    NaN    NaN    NaN    NaN
# 2011-10-01    100.0   80.0   64.0    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,8))
plt.title("retention")
sns.heatmap(data=retention,
            annot=True,
            fmt='.0%',
            vmin=0.0,
            vmax=0.5,
            cmap='BuGn')
plt.show()

# %% [markdown]
# # RFM Analysis

# %% [markdown]
# 1. Recency : How recent was the customers last purchase (days diff)
# 2. Frequency : Number of purchases in last 12 months (count of purchases)
# 3. Money value : how much spend in last 12 month (rupee)

# %%
Pl_activity_ca.head(2)
# Out:
# 0 src_player_id ActivityMonth   Product_x Net_Gross_Win ActivePlayerDays  \
# 0      16585649    2020-08-31  SportsBook           420                1
# 1      12845036    2019-05-31  SportsBook       34.9692               28
#
# 0 BONUS_COST Src_Player_Id         Signup_Date acquisition_channel revenue  \
# 0        NaN      16585649 2020-08-06 12:27:56                 PPC     NaN
# 1        NaN      12845036 2019-04-20 22:05:39                 PPC     NaN
#
# 0 Cohort_month  period
# 0        20-08       0
# 1        19-04       1

# %%
revenue_quartiles = pd.qcut(Pl_activity_ca["revenue"], q=4, labels=range(1,5))

# %%
Pl_activity_ca["revenue_quartiles"] = revenue_quartiles

# %%
print(Pl_activity_ca["ActivityMonth"].max())
# Out:
# 2021-06-30 00:00:00

# %%
last_activity_freq = Pl_activity_ca.groupby("src_player_id")["ActivityMonth"].max().reset_index()
last_activity_freq.rename(columns={"ActivityMonth": "LastActivityDate"}, inplace=True)

# %%
last_activity_freq
# Out:
#         src_player_id LastActivityDate
# 0            12329393       2019-01-31
# 1            12329407       2019-01-31
# 2            12329630       2019-01-31
# 3            12329932       2019-01-31
# 4            12329942       2019-01-31
# ...               ...              ...
# 167322       20701685       2021-06-30
# 167323       20702081       2021-06-30
# 167324       20702367       2021-06-30
# 167325       20703294       2021-06-30
# 167326       20703585       2021-06-30
#
# [167327 rows x 2 columns]

# %%
last_activity_freq["last_date"] = pd.to_datetime("2021-06-30")

# %%
# frequency

last_activity_freq["MonthsSinceLastActivity"] = ((last_activity_freq["last_date"].dt.year - last_activity_freq["LastActivityDate"].dt.year) * 12 +
                                            (last_activity_freq["last_date"].dt.month - last_activity_freq["LastActivityDate"].dt.month))

# %%
r_labels = list(range(4,0,-1))

# %%
last_activity_freq["recency_quartiles"] = recency_quartiles

# %%
recency_quartiles = pd.qcut(last_activity_freq["MonthsSinceLastActivity"], q=4, labels=r_labels)

# %%
last_activity_freq.head(2)
# Out:
#    src_player_id LastActivityDate  last_date  MonthsSinceLastActivity  \
# 0       12329393       2019-01-31 2021-06-30                       29
# 1       12329407       2019-01-31 2021-06-30                       29
#
#   recency_quartiles
# 0                 1
# 1                 1
